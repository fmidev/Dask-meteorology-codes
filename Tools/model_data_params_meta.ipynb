# %% [raw]
# """ Mahdolliset parametrit ecmwf_eurooppa_pinta tuottajalle:
# DewPoint,
# FogIntensity,
# eopHeight,
# HighCloudCover,
# HourlyMaximumGust,
# HourlyMaximumWindSpeed,
# Humidity,LowCloudCover,
# MediumCloudCover,
# MiddleAndLowCloudCover,
# PoP,
# PotentialPrecipitationForm,
# PotentialPrecipitationType,
# Precipitation1h,
# PrecipitationForm,
# PrecipitationForm2,
# PrecipitationRate,
# PrecipitationType,
# Pressure,
# ProbabilityThunderstorm,
# RadiationGlobal,
# RadiationLW,
# SmartSymbol,
# Temperature,
# TotalCloudCover,
# WeatherNumber,
# WeatherSymbol1,
# WeatherSymbol3,
# WindDirection,
# WindGust,
# WindSpeedMS,
# WindUMS,
# WindVMS,
# WindVectorMS
# """

# %% [raw]
# """ Mahdolliset parametrit harmonie_skandinavia_pinta tuottajalle:
# DewPoint,
# FogIntensity,
# eopHeight,
# HighCloudCover,
# HourlyMaximumGust,
# HourlyMaximumWindSpeed,
# Humidity,LowCloudCover,
# MediumCloudCover,
# MiddleAndLowCloudCover,
# PoP,
# PotentialPrecipitationForm,
# PotentialPrecipitationType,
# Precipitation1h,
# PrecipitationForm,
# PrecipitationForm2,
# PrecipitationRate,
# PrecipitationType,
# Pressure,
# ProbabilityThunderstorm,
# RadiationGlobal,
# RadiationLW,
# SmartSymbol,
# Temperature,
# TotalCloudCover,
# WeatherNumber,
# WeatherSymbol1,
# WeatherSymbol3,
# WindDirection,
# WindGust,
# WindSpeedMS,
# WindUMS,
# WindVMS,
# WindVectorMS
# """

# %% [raw]
# """ Mahdolliset parametrit gfs_skandinavia_pinta tuottajalle:
# DewPoint,
# FogIntensity,
# eopHeight,
# HighCloudCover,
# HourlyMaximumGust,
# HourlyMaximumWindSpeed,
# Humidity,LowCloudCover,
# MediumCloudCover,
# MiddleAndLowCloudCover,
# PoP,
# PotentialPrecipitationForm,
# PotentialPrecipitationType,
# Precipitation1h,
# PrecipitationForm,
# PrecipitationForm2,
# PrecipitationRate,
# PrecipitationType,
# Pressure,
# ProbabilityThunderstorm,
# RadiationGlobal,
# RadiationLW,
# SmartSymbol,
# Temperature,
# TotalCloudCover,
# WeatherNumber,
# WeatherSymbol1,
# WeatherSymbol3,
# WindDirection,
# WindGust,
# WindSpeedMS,
# WindUMS,
# WindVMS,
# WindVectorMS
# """

# %% [raw]
# """ Mahdolliset parametrit mos_eurooppa_pinta tuottajalle:
# DewPoint,
# FogIntensity,
# eopHeight,
# HighCloudCover,
# HourlyMaximumGust,
# HourlyMaximumWindSpeed,
# Humidity,LowCloudCover,
# MediumCloudCover,
# MiddleAndLowCloudCover,
# PoP,
# PotentialPrecipitationForm,
# PotentialPrecipitationType,
# Precipitation1h,
# PrecipitationForm,
# PrecipitationForm2,
# PrecipitationRate,
# PrecipitationType,
# Pressure,
# ProbabilityThunderstorm,
# RadiationGlobal,
# RadiationLW,
# SmartSymbol,
# Temperature,
# TotalCloudCover,
# WeatherNumber,
# WeatherSymbol1,
# WeatherSymbol3,
# WindDirection,
# WindGust,
# WindSpeedMS,
# WindUMS,
# WindVMS,
# WindVectorMS
# """
